# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-7ed4c17c-579e-4951-ab3c-5e6337574d1b" name="files[]" multiple disabled />
#      <output id="result-7ed4c17c-579e-4951-ab3c-5e6337574d1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving testfile.csv to testfile.csv

# %%
sal = pd.read_csv('testfile.csv')

# %%
sal
# Out:
#       Id       EmployeeName  ...         Agency  Status
# 0      1     NATHANIEL FORD  ...  San Francisco     NaN
# 1      2       GARY JIMENEZ  ...  San Francisco     NaN
# 2      3     ALBERT PARDINI  ...  San Francisco     NaN
# 3      4  CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4      5    PATRICK GARDNER  ...  San Francisco     NaN
# ..   ...                ...  ...            ...     ...
# 145  146     ANTHONY DUMONT  ...  San Francisco     NaN
# 146  147    THERESA DENTONI  ...  San Francisco     NaN
# 147  148          TIM AREJA  ...  San Francisco     NaN
# 148  149      SIU-KWAN CHOW  ...  San Francisco     NaN
# 149  150      PATRICIA CARR  ...  San Francisco     NaN
#
# [150 rows x 13 columns]

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                150 non-null    int64
#  1   EmployeeName      150 non-null    object
#  2   JobTitle          150 non-null    object
#  3   BasePay           150 non-null    float64
#  4   OvertimePay       150 non-null    float64
#  5   OtherPay          150 non-null    float64
#  6   Benefits          0 non-null      float64
#  7   TotalPay          150 non-null    float64
#  8   TotalPayBenefits  150 non-null    float64
#  9   Year              150 non-null    int64
#  10  Notes             0 non-null      float64
#  11  Agency            150 non-null    object
#  12  Status            0 non-null      float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 15.4+ KB

# %%
sal.head()
# Out:
#    Id       EmployeeName  ...         Agency  Status
# 0   1     NATHANIEL FORD  ...  San Francisco     NaN
# 1   2       GARY JIMENEZ  ...  San Francisco     NaN
# 2   3     ALBERT PARDINI  ...  San Francisco     NaN
# 3   4  CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4   5    PATRICK GARDNER  ...  San Francisco     NaN
#
# [5 rows x 13 columns]

# %%
sal.tail()
# Out:
#       Id     EmployeeName  ...         Agency  Status
# 145  146   ANTHONY DUMONT  ...  San Francisco     NaN
# 146  147  THERESA DENTONI  ...  San Francisco     NaN
# 147  148        TIM AREJA  ...  San Francisco     NaN
# 148  149    SIU-KWAN CHOW  ...  San Francisco     NaN
# 149  150    PATRICIA CARR  ...  San Francisco     NaN
#
# [5 rows x 13 columns]

# %%
sal['BasePay'].mean()
# Out:
# 168218.90913333328

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sal[sal['EmployeeName'] == 'ALSON LEE']['TotalPayBenefits']
# Out:
# 6    315981.05
# Name: TotalPayBenefits, dtype: float64

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName  ...         Agency  Status
# 0   1  NATHANIEL FORD  ...  San Francisco     NaN
#
# [1 rows x 13 columns]

# %%
sal['BasePay'].max()
# Out:
# 294580.02

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    168218.909133
# Name: BasePay, dtype: float64

# %%
sal['JobTitle'].max()
# Out:
# 'WIRE ROPE CABLE MAINTENANCE MECHANIC'

# %%
sal['JobTitle'].nunique()
# Out:
# 47

# %%
sal['JobTitle'].value_counts().tail(7)
# Out:
# ADMINISTRATOR, SFGH MEDICAL CENTER                    1
# SERGEANT III (POLICE DEPARTMENT)                      1
# SUPERVISING PHYSICIAN SPECIALIST                      1
# POLICE OFFICER III                                    1
# ELECTRONIC MAINTENANCE TECHNICIAN                     1
# CHIEF OF POLICE                                       1
# INSPECTOR, BUREAU OF FIRE PREVENTION AND PUBLIC SA    1
# Name: JobTitle, dtype: int64

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                150 non-null    int64
#  1   EmployeeName      150 non-null    object
#  2   JobTitle          150 non-null    object
#  3   BasePay           150 non-null    float64
#  4   OvertimePay       150 non-null    float64
#  5   OtherPay          150 non-null    float64
#  6   Benefits          0 non-null      float64
#  7   TotalPay          150 non-null    float64
#  8   TotalPayBenefits  150 non-null    float64
#  9   Year              150 non-null    int64
#  10  Notes             0 non-null      float64
#  11  Agency            150 non-null    object
#  12  Status            0 non-null      float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 15.4+ KB

# %%
sns.pairplot(sal)
