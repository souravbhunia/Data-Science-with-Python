# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-9bae3370-a019-4052-b7db-5288056404b0" name="files[]" multiple disabled />
#      <output id="result-9bae3370-a019-4052-b7db-5288056404b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.csv to tips.csv

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-69f4092b-ea43-4d2d-88eb-4fd4c5d31b18" name="files[]" multiple disabled />
#      <output id="result-69f4092b-ea43-4d2d-88eb-4fd4c5d31b18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving testfile.csv to testfile.csv

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-5c86ad44-f8cd-466d-978a-b9f2db6446c9" name="files[]" multiple disabled />
#      <output id="result-5c86ad44-f8cd-466d-978a-b9f2db6446c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AirPassengers.csv to AirPassengers.csv

# %%
flights =pd.read_csv('AirPassengers.csv')
sal=pd.read_csv('testfile.csv')
tips=pd.read_csv('tips.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b9dca92e3e1e> in <module>()
# ----> 1 flights =pd.read_csv('AirPassengers.csv')
#       2 sal=pd.read_csv('testfile.csv')
#       3 tips=pd.read_csv('tips.csv')
#
# NameError: name 'pd' is not defined

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                150 non-null    int64
#  1   EmployeeName      150 non-null    object
#  2   JobTitle          150 non-null    object
#  3   BasePay           150 non-null    float64
#  4   OvertimePay       150 non-null    float64
#  5   OtherPay          150 non-null    float64
#  6   Benefits          0 non-null      float64
#  7   TotalPay          150 non-null    float64
#  8   TotalPayBenefits  150 non-null    float64
#  9   Year              150 non-null    int64
#  10  Notes             0 non-null      float64
#  11  Agency            150 non-null    object
#  12  Status            0 non-null      float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 15.4+ KB

# %%
import seaborn as sns
import numpy as std

# %%
sns.barplot(x='sex',y='total_bill', data=tips)

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                150 non-null    int64
#  1   EmployeeName      150 non-null    object
#  2   JobTitle          150 non-null    object
#  3   BasePay           150 non-null    float64
#  4   OvertimePay       150 non-null    float64
#  5   OtherPay          150 non-null    float64
#  6   Benefits          0 non-null      float64
#  7   TotalPay          150 non-null    float64
#  8   TotalPayBenefits  150 non-null    float64
#  9   Year              150 non-null    int64
#  10  Notes             0 non-null      float64
#  11  Agency            150 non-null    object
#  12  Status            0 non-null      float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 15.4+ KB

# %%
sns.barplot(x='BasePay' ,y='TotalPayBenefits',data=sal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b7e29bcd04b0> in <module>()
# ----> 1 sns.barplot(x='BasePay' ,y='TotalPayBenefits',data=sal)
#
# NameError: name 'sns' is not defined

# %%
sns.barplot(x='JobTitle' ,y='TotalPay', data=sal)

# %%
sns.catplot(x='JobTitle', data=sal)

# %%
sns.countplot(x='sex', data=tips)
sns.countplot(x='BasePay', data=sal)

# %%
flights.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-223c16f794bb> in <module>()
# ----> 1 flights.info()
#
# NameError: name 'flights' is not defined

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
sns.countplot(x='sex', data=tips)

# %%
sns.boxplot(y="BasePay", y="TotalPayBenefits", data=sal,palette='rainbow')
# Out:
#   File "<ipython-input-60-ac20854ffd2b>", line 1
#     sns.boxplot(y="BasePay", y="TotalPayBenefits", data=sal,palette='rainbow')
#                             ^
# SyntaxError: keyword argument repeated

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sal.corr()
# Out:
#                         Id   BasePay  OvertimePay  ...  Year  Notes  Status
# Id                1.000000 -0.207178    -0.135142  ...   NaN    NaN     NaN
# BasePay          -0.207178  1.000000    -0.628817  ...   NaN    NaN     NaN
# OvertimePay      -0.135142 -0.628817     1.000000  ...   NaN    NaN     NaN
# OtherPay         -0.294614 -0.396447    -0.032802  ...   NaN    NaN     NaN
# Benefits               NaN       NaN          NaN  ...   NaN    NaN     NaN
# TotalPay         -0.695474  0.111409     0.207636  ...   NaN    NaN     NaN
# TotalPayBenefits -0.695474  0.111409     0.207636  ...   NaN    NaN     NaN
# Year                   NaN       NaN          NaN  ...   NaN    NaN     NaN
# Notes                  NaN       NaN          NaN  ...   NaN    NaN     NaN
# Status                 NaN       NaN          NaN  ...   NaN    NaN     NaN
#
# [10 rows x 10 columns]

# %%
flights.corr()
# Out:
#              #Passengers
# #Passengers          1.0

# %%
sal.corr() 
flights.corr()
# Out:
#              #Passengers
# #Passengers          1.0

# %%
sns.heatmap(flights.corr())

# %%
sns.heatmap(sal.corr())

# %%
sns.heatmap(tips.corr())

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %%
#it is not use in industry
sns.heatmap(tips.corr(),cmap='rainbow',annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49285ccef85c> in <module>()
# ----> 1 sns.heatmap(tips.corr(),cmap='rainbow',annot=True)
#
# NameError: name 'sns' is not defined
